# %%
# !pip install ibm-watsonx-ai langchain langchain-ibm langchain-community gradio chromadb pypdf
# Out:
# Requirement already satisfied: ibm-watsonx-ai in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (0.2.11)
# Requirement already satisfied: langchain-ibm in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (0.1.11)
# Requirement already satisfied: langchain-community in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (0.2.10)
# Requirement already satisfied: gradio in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (4.44.0)
# Requirement already satisfied: chromadb in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (0.4.24)
# Requirement already satisfied: pypdf in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (4.3.1)
# Requirement already satisfied: requests in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (2.32.2)
# Requirement already satisfied: urllib3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (2.0.4)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (2.1.4)
# Requirement already satisfied: certifi in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (2023.7.22)
# Requirement already satisfied: lomond in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (0.3.3)
# Requirement already satisfied: tabulate in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (0.9.0)
# Requirement already satisfied: packaging in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-watsonx-ai) (7.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (3.11.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.9.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (3.11.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydub in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.12.10)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (4.13.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio) (0.28.0)
# Requirement already satisfied: fsspec in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio-client==1.3.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.7.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (3.8.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.57b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: idna>=2.8 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from anyio<5.0,>=3.0->gradio) (2.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: pyproject_hooks in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1.0->gradio) (0.47.3)
# Requirement already satisfied: httpcore==1.* in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.4)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai) (2.9.0.post0)
# Requirement already satisfied: six>=1.9.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.6.1)
# Requirement already satisfied: requests-oauthlib in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: coloredlogs in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata->ibm-watsonx-ai) (3.17.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.57b0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.57b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.57b0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.57b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.57b0)
# Requirement already satisfied: opentelemetry-util-http==0.57b0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.57b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.57b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.57b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.7.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai) (2023.3)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from requests->ibm-watsonx-ai) (3.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain) (2.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.16.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\harsh modi\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import warnings
from types import SimpleNamespace

# --- Suppress noisy warnings for a clean UI (optional) ---
def warn(*args, **kwargs):
    pass
warnings.warn = warn
warnings.filterwarnings("ignore")

# %%
# --- LangChain & IBM watsonx ---
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain_ibm import WatsonxLLM, WatsonxEmbeddings

# %%
# --- UI ---
import gradio as gr


# =========================
# LLM: watsonx Granite 3
# =========================
def get_llm():
    """
    Returns a WatsonxLLM instance (Granite 3 8B Instruct).
    Reads credentials from env vars:
        WATSONX_APIKEY, WATSONX_URL, WATSONX_PROJECT_ID
    """
    model_id = "ibm/granite-3-8b-instruct"
    params = {
        "temperature": 0.5,
        "max_new_tokens": 256,
        "decoding_method": "sample",
    }

    apikey = os.getenv("WATSONX_APIKEY")
    url = os.getenv("WATSONX_URL", "https://us-south.ml.cloud.ibm.com")
    project_id = os.getenv("WATSONX_PROJECT_ID", "skills-network")

    if not apikey:
        raise RuntimeError(
            "Missing WATSONX_APIKEY. Set it as an environment variable."
        )

    llm = WatsonxLLM(
        model_id=model_id,
        url=url,
        apikey=apikey,
        project_id=project_id,
        params=params,
    )
    return llm

# %%
# ==================================
# 1) Document Loader (PyPDFLoader)
#    📸 Take screenshot: pdf_loader.png
# ==================================
def document_loader(file_path: str):
    """
    Loads a PDF and returns LangChain Documents list.
    Accepts a filesystem path string (Gradio provides this when type='filepath').
    """
    loader = PyPDFLoader(file_path)
    loaded_docs = loader.load()
    return loaded_docs

# %%
# ========================================
# 2) Text Splitter (RecursiveCharacter)
#    📸 Take screenshot: code_splitter.png
# ========================================
def text_splitter(documents):
    """
    Splits docs into manageable chunks.
    chunk_size/overlap tuned for RAG with small context windows.
    """
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=200,
        length_function=len,
    )
    chunks = splitter.split_documents(documents)
    return chunks

# %%
# ===========================================
# 3) Embeddings (WatsonxEmbeddings)
#    📸 Take screenshot: embedding.png
# ===========================================
def watsonx_embedding():
    """
    Returns a WatsonxEmbeddings model for semantic vectors.
    Uses a small, fast retriever model (slate-125m).
    """
    apikey = os.getenv("WATSONX_APIKEY")
    url = os.getenv("WATSONX_URL", "https://us-south.ml.cloud.ibm.com")
    project_id = os.getenv("WATSONX_PROJECT_ID", "skills-network")

    if not apikey:
        raise RuntimeError(
            "Missing WATSONX_APIKEY. Set it as an environment variable."
        )

    embed_params = {
        "truncation": True,
    }
    embedding = WatsonxEmbeddings(
        model_id="ibm/slate-125m-english-rtrvr",
        url=url,
        apikey=apikey,
        project_id=project_id,
        params=embed_params,
    )
    return embedding

# %%
# ====================================================
# 4) Vector DB (Chroma from_documents)
#    📸 Take screenshot: vectordb.png
# ====================================================
def vector_database(chunks):
    """
    Creates an in-memory Chroma vector store from chunks using watsonx embeddings.
    (No persistence; add persist_directory=... to persist between runs.)
    """
    embedding_model = watsonx_embedding()
    vectordb = Chroma.from_documents(
        documents=chunks,
        embedding=embedding_model,
        # persist_directory="chroma_store"  # optional: uncomment to persist
    )
    return vectordb

# %%
# =========================================
# 5) Retriever (similarity search)
#    📸 Take screenshot: retriever.pnga
# =========================================
def retriever(file_path: str):
    """
    Full pipeline:
      load -> split -> embed -> build vector DB -> return retriever
    """
    docs = document_loader(file_path)
    chunks = text_splitter(docs)
    vectordb = vector_database(chunks)
    retr = vectordb.as_retriever(search_type="similarity", search_kwargs={"k": 4})
    return retr

# %%
# ==========================================================
# 6) RetrievalQA Chain + Gradio Interface (the QA Bot)
#    📸 Take screenshot in the browser: QA_bot.png
#       - Interface visible
#       - PDF uploaded
#       - Query = "What this paper is talking about?"
# ==========================================================
def retriever_qa(file_path: str, query: str) -> str:
    """
    Build a RetrievalQA chain using:
      - LLM: Granite 3 8B Instruct
      - Retriever: Chroma similarity over PDF chunks
    Returns only the final answer string.
    """
    if not file_path:
        return "Please upload a PDF first."

    llm = get_llm()
    retr_obj = retriever(file_path)

    qa = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retr_obj,
        return_source_documents=False,  # set True if you want to inspect sources
    )
    # LCEL .invoke expects {"query": "..."} for RetrievalQA
    result = qa.invoke({"query": query or "What this paper is talking about?"})
    # Depending on LC version, result may be dict or str; handle both safely:
    if isinstance(result, dict) and "result" in result:
        return result["result"]
    if isinstance(result, str):
        return result
    return str(result)

# %%
# ======================
# Gradio App
# ======================
app_title = "Document Q&A Bot"
app_desc = (
    "Upload a PDF and ask any question. "
    "The bot will answer using the document via RAG (LangChain + watsonx)."
)

demo = gr.Interface(
    fn=lambda pdf_path, query: retriever_qa(pdf_path, query),
    inputs=[
        gr.File(
            label="Upload PDF File",
            file_count="single",
            file_types=[".pdf"],
            type="filepath",  # IMPORTANT: we pass a path string to our functions
        ),
        gr.Textbox(
            label="Input Query",
            lines=2,
            placeholder='Type your question here… e.g., "What this paper is talking about?"',
            value="What this paper is talking about?",
        ),
    ],
    outputs=gr.Textbox(label="Answer"),
    title=app_title,
    description=app_desc,
    allow_flagging="never",
)

# %%
if __name__ == "__main__":
    demo.launch(server_name="0.0.0.0", server_port=7861)
# Out:
# Running on local URL:  http://0.0.0.0:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3310354587.py", line 11, in <lambda>
#     fn=lambda pdf_path, query: retriever_qa(pdf_path, query),
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3790358043.py", line 18, in retriever_qa
#     llm = get_llm()
#           ^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3444642559.py", line 26, in get_llm
#     raise RuntimeError(
# RuntimeError: Missing WATSONX_APIKEY. Set it as an environment variable.

# %%
# !taskkill /PID 12345 /F
# Out:
# ERROR: The process "12345" not found.
# Traceback (most recent call last):
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1935, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1520, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\utils.py", line 826, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3310354587.py", line 11, in <lambda>
#     fn=lambda pdf_path, query: retriever_qa(pdf_path, query),
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3790358043.py", line 18, in retriever_qa
#     llm = get_llm()
#           ^^^^^^^^^
#   File "C:\Users\Harsh Modi\AppData\Local\Temp\ipykernel_12412\3444642559.py", line 26, in get_llm
#     raise RuntimeError(
# RuntimeError: Missing WATSONX_APIKEY. Set it as an environment variable.
